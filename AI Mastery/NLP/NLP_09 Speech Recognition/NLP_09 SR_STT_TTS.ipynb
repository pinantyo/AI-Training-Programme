# %% [markdown]
# # Bagian MFCC adalah membandingkan antara pakai teknik MFCC saja dan dengan penambahan fungsi Delta-Delta

# %% [markdown]
# # MFCC With Delta untuk 26 feature, dengan 13 dari MFCC dan 13 dari Delta, fitur dapat di update hingga 40 dengan 20 MFCC dan 20 Delta, jadi dapat meningkatkan akurasi, hanya saja komputasi juga akan lebih berat dan lama.

# %% [markdown]
# Link: http://www.practicalcryptography.com/miscellaneous/machine-learning/guide-mel-frequency-cepstral-coefficients-mfccs/

# %% [markdown]
# Link all audio dapat di download disini https://github.com/Wayan123/data-rekaman

# %% [markdown]
# # Install library MFCC

# %%
# !pip install python_speech_features
# Out:
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
# Building wheels for collected packages: python-speech-features
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=6ae29621af734cef513c9608ced28ba040769c76c442451dab9fecd389cafd24
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built python-speech-features
# Installing collected packages: python-speech-features
# Successfully installed python-speech-features-0.6

# %% [markdown]
# # Import Library yang dibutuhkan

# %%
from python_speech_features import mfcc   # Import library MFCC
from python_speech_features import delta  # Memanggil fungsi delta 
from python_speech_features import logfbank # menggail fungsi log filter bank
import scipy.io.wavfile as wav # library untuk menanangi file dengan format .wav

# %% [markdown]
# Download Audio : https://s.id/14aLR

# %% [markdown]
# ## Load file wav dari lokal komputer

# %%
path_file = "halo.wav"

# %% [markdown]
# ## Memutar audio yang di upload dengan menggunakan library Ipython

# %%
import IPython.display as ipd
ipd.Audio(path_file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Melakukan tahap preprocessing pada audio menggunakan MFCC

# %%
(rate,sig) = wav.read(path_file)
mfcc_feat = mfcc(sig,rate)
d_mfcc_feat = delta(mfcc_feat, 2)
fbank_feat = logfbank(sig,rate)
# Out:
# WARNING:root:frame length (1200) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (1200) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.

# %% [markdown]
# Info lebih lengkap mengenai masing-masing fungsi pada MFCC dapat dibaca di documentation berikut:
# 1. https://python-speech-features.readthedocs.io/en/latest/
# 2. https://github.com/jameslyons/python_speech_features (github)
# 3. http://www.practicalcryptography.com/miscellaneous/machine-learning/guide-mel-frequency-cepstral-coefficients-mfccs/ (tutorial)

# %% [markdown]
# ## Menampilkan hasil ekstraksi ciri menggunakan MFCC + Fungsi Delta dengan masing2 13 feature, jadi total 26 feature.

# %%
print(fbank_feat[1:3,:])
# Out:
# [[-3.16598881 -2.94555617 -1.5571456  -0.74740389 -1.97664765 -1.70015689
#   -1.18586245  0.24346435  0.0280794  -0.35474778 -0.13769651  0.71059688
#    0.97824869  1.45554893  2.73485392  2.72305196  1.93942239  1.77219602
#    1.82513022  1.93141409  1.76125314  1.90902166  1.6142979   1.43544537
#    1.36807072  0.44516651]
#  [-3.51893297 -3.51675722 -1.14814285 -0.48588787 -1.36371385 -0.31521181
#   -0.85310367  0.95630269  0.47325892  0.25987184  0.23319996  1.31941601
#    1.89242548  2.58264237  3.54488005  3.66045005  2.51531696  2.14811473
#    1.74338309  1.5361042   1.58167417  1.60919553  1.36512101  1.35203758
#    2.07936695  1.3415236 ]]

# %%
fbank_feat
# Out:
# array([[-4.12956797, -5.87997086, -4.24183328, ...,  0.52541995,
#          0.2149384 , -0.7697643 ],
#        [-3.16598881, -2.94555617, -1.5571456 , ...,  1.43544537,
#          1.36807072,  0.44516651],
#        [-3.51893297, -3.51675722, -1.14814285, ...,  1.35203758,
#          2.07936695,  1.3415236 ],
#        ...,
#        [-2.08445187, -5.48788977, -2.56845825, ...,  1.6161509 ,
#          2.85799536,  1.91645021],
#        [-3.93024005, -4.45920477, -3.93491541, ...,  1.14777927,
#          2.57788928,  1.71729057],
#        [-4.91298633, -4.91309928, -4.50791029, ..., -3.14233287,
#         -3.65483489, -4.66742295]])

# %% [markdown]
# Tampilkan total baris feature

# %%
data = len(fbank_feat)
data
# Out:
# 541

# %% [markdown]
# Menyimpan file hasil ekstraksi ke format csv menggunakan library pandas

# %%
import pandas as pd 
   
df = pd.DataFrame(fbank_feat)
# saving the dataframe
df.to_csv('extract_delta_halo.csv')

# %%
# Kita juga dapat menampilkan format yang telah disimpan disini

df
# Out:
#            0         1         2         3         4         5         6   \
# 0   -4.129568 -5.879971 -4.241833 -4.989389 -2.861421 -2.966936 -2.700614
# 1   -3.165989 -2.945556 -1.557146 -0.747404 -1.976648 -1.700157 -1.185862
# 2   -3.518933 -3.516757 -1.148143 -0.485888 -1.363714 -0.315212 -0.853104
# 3   -1.752291 -7.030204 -1.331094 -1.668017 -0.901192 -0.171546  0.401569
# 4   -4.036866 -3.534945 -3.198817 -1.006781  0.293161 -0.802727 -0.131720
# ..        ...       ...       ...       ...       ...       ...       ...
# 536 -4.498236 -5.724434 -2.002418 -2.138763 -1.177996 -0.814602  0.666336
# 537 -4.387551 -4.476447 -2.907068 -2.424621 -1.933661 -1.859559 -0.805678
# 538 -2.084452 -5.487890 -2.568458 -3.328768 -1.323159 -1.569519 -1.136011
# 539 -3.930240 -4.459205 -3.934915 -3.412464 -2.385769 -1.876264 -0.725356
# 540 -4.912986 -4.913099 -4.507910 -4.508312 -4.221496 -3.999521 -4.001531
#
#            7         8         9   ...        16        17        18  \
# 0   -2.200633 -1.031048 -0.673971  ...  0.520101  1.114239  0.720384
# 1    0.243464  0.028079 -0.354748  ...  1.939422  1.772196  1.825130
# 2    0.956303  0.473259  0.259872  ...  2.515317  2.148115  1.743383
# 3    0.573932  1.320525  1.397543  ...  2.660136  2.661138  1.989389
# 4    0.503538  0.541143  1.489655  ...  2.928795  2.780584  1.636963
# ..        ...       ...       ...  ...       ...       ...       ...
# 536  2.526697 -0.064729  0.972730  ...  6.537178  5.260948  3.197573
# 537 -0.187283 -0.538966  0.090470  ...  3.293089  2.912425  1.979719
# 538 -0.341682 -1.874467 -0.541444  ...  3.581076  2.466884  1.756075
# 539 -0.344736 -0.627409 -0.444540  ...  3.167638  2.197596  1.436894
# 540 -3.821775 -3.825287 -3.675862  ... -2.817101 -2.771795 -2.711626
#
#            19        20        21        22        23        24        25
# 0    1.142014  0.799007  0.430767  0.721092  0.525420  0.214938 -0.769764
# 1    1.931414  1.761253  1.909022  1.614298  1.435445  1.368071  0.445167
# 2    1.536104  1.581674  1.609196  1.365121  1.352038  2.079367  1.341524
# 3    1.643275  1.684112  1.734520  1.512506  1.604377  2.492732  2.043558
# 4    1.524342  1.733112  2.030871  1.521962  1.484396  2.480620  1.710401
# ..        ...       ...       ...       ...       ...       ...       ...
# 536  2.271950  1.930241  1.787598  1.869999  3.421912  5.793653  4.883581
# 537  2.630475  2.577929  2.107022  2.439171  1.971986  3.205707  2.716495
# 538  2.173025  2.292828  1.953931  2.113727  1.616151  2.857995  1.916450
# 539  1.410576  1.744460  2.162223  1.520214  1.147779  2.577889  1.717291
# 540 -2.657481 -2.690878 -2.732140 -2.848610 -3.142333 -3.654835 -4.667423
#
# [541 rows x 26 columns]

# %% [markdown]
# # MFCC Pembahasan Lengkap Tanpa Fungsi Delta dan Double Delta

# %% [markdown]
# Link:
# 1. https://towardsdatascience.com/extract-features-of-music-75a3f9bc265d
# 2. https://python-speech-features.readthedocs.io/en/latest/
# 3. https://www.programcreek.com/python/example/105369/python_speech_features.delta
# 4. https://github.com/jameslyons/python_speech_features/blob/master/docs/source/index.rst
# 5. https://github.com/jameslyons/python_speech_features

# %%
import librosa

audio_path = 'halo.wav'
x , sr = librosa.load(audio_path)
print(type(x), type(sr))
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %% [markdown]
# Menentukan Sample Rate 44,1 KHz

# %%
librosa.load(audio_path, sr=44100)
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 44100)

# %% [markdown]
# Jika Sample Rate tidak ditentukan, maka default 48 KHz

# %%
librosa.load(audio_path, sr=None)
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 48000)

# %%
import IPython.display as ipd
ipd.Audio(audio_path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#display waveform

# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
#display Spectrogram

X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
x, sr = librosa.load(audio_path)
#Plot the signal:
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
print(len(x), sr)
# Out:
# 59741 22050

# %%
# Zooming in
n0 = 20000
n1 = 25000
plt.figure(figsize=(14, 5))
plt.plot(x[n0:n1])
plt.grid()

# %%
zero_crossings = librosa.zero_crossings(x[n0:n1], pad=False)
print(sum(zero_crossings))
# Out:
# 615

# %%
#spectral centroid -- centre of mass -- weighted mean of the frequencies present in the sound
import sklearn
spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)[0]
spectral_centroids.shape
# Computing the time variable for visualization
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)
# Normalising the spectral centroid for visualisation
def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)
#Plotting the Spectral Centroid along the waveform
librosa.display.waveplot(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_centroids), color='r')

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)[0]
librosa.display.waveplot(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (20, 117)

# %%
mfccs
# Out:
# array([[-6.2270508e+02, -5.0458163e+02, -4.5602768e+02, ...,
#         -6.4199915e+02, -6.4199915e+02, -6.4199915e+02],
#        [ 2.0478020e+01,  5.3783165e+01,  4.9097401e+01, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [ 1.1525576e+01,  3.7323556e+00,  2.8984215e+00, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        ...,
#        [-2.3695078e+00,  2.0847573e+00, -1.5159869e+00, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [-3.5600166e+00, -5.6268997e+00, -1.0617421e+01, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [-1.3575857e+00, -5.3889024e-01,  2.6578815e+00, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00]], dtype=float32)

# %%
import pandas as pd 
   
df1 = pd.DataFrame(mfccs)
# saving the dataframe
df.to_csv('extract_delta_hai.csv')

# %%
df1
# Out:
#            0           1           2           3           4           5    \
# 0  -622.705078 -504.581635 -456.027679 -465.815613 -475.541168 -488.204041
# 1    20.478020   53.783165   49.097401   41.162155   43.770866   46.720192
# 2    11.525576    3.732356    2.898422    5.044723    3.946448    0.147232
# 3     5.151940   -5.058527   -1.587143    4.021379    3.633081   -2.443921
# 4     7.319065   13.757004   13.183794   12.853367    6.690754    1.539970
# 5     8.298645   -4.148193   -8.957895   -9.088411  -11.861135  -12.342098
# 6     7.346175    0.215335   -5.599253   -9.207712   -8.844069   -8.175665
# 7     3.286644   -0.186620   -4.988381   -9.073476   -2.668963   -3.394655
# 8    -1.204347   -4.044868   -6.516029  -10.099932   -7.092111   -8.767132
# 9    -3.678270    4.852245    1.465811   -6.720787   -6.528602   -5.158067
# 10   -3.267806   -2.514499   -5.784900  -11.650988  -10.622466  -11.459328
# 11    1.685796    7.408001    7.134728    4.460953    3.832485    3.146914
# 12    2.678193   -4.706857  -11.089826  -16.346165  -16.173927  -14.508008
# 13    1.312981    2.689312    0.176570   -7.130531   -9.486328   -2.311771
# 14   -3.730721  -12.982010  -14.024748  -17.990433  -19.887928  -17.382431
# 15   -3.157707   -1.059094   -0.458047   -1.091189   -3.436039   -3.857556
# 16   -3.505045  -17.078217  -13.925631  -13.113325  -15.034435  -14.934788
# 17   -2.369508    2.084757   -1.515987   -5.075801   -4.019716   -3.706882
# 18   -3.560017   -5.626900  -10.617421  -15.288172  -12.417796  -13.038668
# 19   -1.357586   -0.538890    2.657881   -1.079154   -4.265105   -5.473496
#
#            6           7           8           9    ...         107  \
# 0  -498.115448 -509.948547 -524.562561 -537.717651  ... -641.999146
# 1    45.989441   50.163902   51.535172   48.938988  ...    0.000000
# 2    -0.346976    6.979072    7.056566    5.003961  ...    0.000000
# 3   -11.734683  -10.451924   -6.749591   -9.306953  ...    0.000000
# 4    -3.972846    0.374419    2.142072    1.017736  ...    0.000000
# 5   -10.000032  -11.735937  -13.750361  -12.743216  ...    0.000000
# 6    -5.197715   -8.416420   -8.502890   -5.230570  ...    0.000000
# 7    -2.835197   -4.433867   -5.747723   -4.867854  ...    0.000000
# 8    -9.164930   -7.899070   -9.082130   -8.536243  ...    0.000000
# 9    -6.394287   -6.749040   -3.559335   -1.576230  ...    0.000000
# 10  -12.515901  -17.303501  -10.422091   -4.042798  ...    0.000000
# 11    2.066688   -3.960656    2.689613    3.588809  ...    0.000000
# 12   -7.229142   -9.106487   -4.458141  -10.114952  ...    0.000000
# 13    4.099086    2.130385    0.070737    0.183800  ...    0.000000
# 14  -13.206318  -16.152672  -15.940977  -14.716386  ...    0.000000
# 15   -2.141778    0.790668    1.051565   -2.622899  ...    0.000000
# 16  -15.977232  -10.813035   -7.313716   -9.897005  ...    0.000000
# 17   -2.775416   -1.852825   -4.293853   -0.814271  ...    0.000000
# 18  -13.160394  -13.629948  -14.113168  -10.275951  ...    0.000000
# 19   -6.957605   -6.757957   -6.836556   -6.772678  ...    0.000000
#
#            108         109         110         111         112         113  \
# 0  -641.999146 -641.999146 -641.999146 -641.999146 -641.999146 -641.999146
# 1     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 2     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 3     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 4     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 5     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 6     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 7     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 8     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 9     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 10    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 11    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 12    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 13    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 14    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 15    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 16    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 17    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 18    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 19    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#
#            114         115         116
# 0  -641.999146 -641.999146 -641.999146
# 1     0.000000    0.000000    0.000000
# 2     0.000000    0.000000    0.000000
# 3     0.000000    0.000000    0.000000
# 4     0.000000    0.000000    0.000000
# 5     0.000000    0.000000    0.000000
# 6     0.000000    0.000000    0.000000
# 7     0.000000    0.000000    0.000000
# 8     0.000000    0.000000    0.000000
# 9     0.000000    0.000000    0.000000
# 10    0.000000    0.000000    0.000000
# 11    0.000000    0.000000    0.000000
# 12    0.000000    0.000000    0.000000
# 13    0.000000    0.000000    0.000000
# 14    0.000000    0.000000    0.000000
# 15    0.000000    0.000000    0.000000
# 16    0.000000    0.000000    0.000000
# 17    0.000000    0.000000    0.000000
# 18    0.000000    0.000000    0.000000
# 19    0.000000    0.000000    0.000000
#
# [20 rows x 117 columns]

# %% [markdown]
# # Speech to Text (STT)

# %% [markdown]
# ## Install Library SpeechRecognition

# %%
# !pip install speechrecognition
# Out:
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      |████████████████████████████████| 32.8 MB 114 kB/s
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.8.1

# %% [markdown]
# ## Import modul google speech recognition, library ini hanya bisa bekerja secara online tidak untuk offline. (Harus menggunakan internet)

# %%
import speech_recognition as sr

# %% [markdown]
# ## Load wav file dari lokal

# %%
path1 = "berbukaPuasa.wav"

# %% [markdown]
# ## Tes memutar file wav

# %%
import IPython.display as ipd
ipd.Audio(path1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Inisialisasi recognizer

# %%
# initialize the recognizer
r = sr.Recognizer()

# %%
# open the file
# Membuka file audio yang di upload
with sr.AudioFile(path1) as source:
    # listen for the data (load audio to memory)
    # Load audio ke memori
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    # konversi audio ke teks dan menggunakan bahasa Indonesia (id), bahasa dapat diganti sesuai dengan kebutuhan
    text = r.recognize_google(audio_data, language='id')
    # Tampilkan isi teks
    print(text)
# Out:
# Selamat berbuka puasa

# %% [markdown]
# # Text to Speech (TTS) menggunakan Google TTS

# %% [markdown]
# ## Install library Google Text to Speech

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gTTS) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gTTS) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from gTTS) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (2.10)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.2.4

# %% [markdown]
# ## Import modul gTTS

# %%
from gtts import gTTS

# %% [markdown]
# ## Masukkan kata-kata yang ingin di konversi disini, dan ubah bahasa sesuai dengan kebutuhan, msialnya teks bahasa Indonesia maka set bahasa ke 'id'

# %%
# Masukkan kata-kata yang ingin di konversi disini, dan ubah bahasa sesuai dengan kebutuhan, msialnya teks bahasa Indonesia maka set bahasa ke 'id'
tts = gTTS('Selamat hari raya idul fitri', lang='id')

# Simpan hasil konversi ke format wav file atau bisa juga format mp3
tts.save('idulFitri.wav')

# %%
import IPython.display as ipd
ipd.Audio('idulFitri.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
