# %% [markdown]
# **Nama**: Steven Christ Pinantyo Arwidarasto
#
# **Kelas**: Alfatih Class
#
# > Buatlah program yang dapat mencetak kata halo dan hai sebanyak 100 kali. contoh: halo hai halo hai … 98x !. Pastikan terdapat spasi di antara setiap perulangan kata!

# %%
for i in range(100):
  print("halo hai",end=" ")
# Out:
# halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai halo hai

# %% [markdown]
# Tabel Kemenangan
#
# ---
# Pemain 1 | Pemain 2 | Pemenang
# --- | --- | ---
# batu | gunting | Pemain 1
# gunting | gunting | Seri
# kertas | gunting | Pemain 2
# gunting | kertas | Pemain 1
# kertas | batu | Pemain 1
#
# > Buatlah game suit batu-gunting-kertas sederhana. Di dalam program tersebut terdapat dua orang pemain yang dapat memilih batu/gunting/kertas menggunakan input dari pengguna. Untuk mempermudah penggambaran aturan pemenang dalam game, lengkapilah tabel kemenangan dengan menggunakan semua kemungkinan yang tersedia.

# %%
game = ["kertas","batu","gunting"]
Player1 = input("Masukan pilihan pemain 1: ")
Player2 = input("Masukan pilihan pemain 2: ")

if(Player1.lower() in game and Player2.lower() in game):
  if(Player1 == Player2):
    print("Seri")
  elif((Player1 == "kertas" and Player2 == "batu") or (Player1 == "gunting" and Player2 == "kertas") or (Player1 == "batu" and Player2 == "gunting")):
    print("Pemain 1")
  else:
    print("Pemain 2")
else:
  print("Input tidak valid!. Gunakan \"batu\", \"gunting\" dan \"kertas\" tanpa tanda kutip!")
# Out:
# Masukan pilihan pemain 1: gunting
# Masukan pilihan pemain 2: kertas
# Pemain 1

# %%
#Test Case
Pemain1 = Pemain2 = ["kertas","batu","gunting"]
for Player1 in Pemain1:
  for Player2 in Pemain2:
    if(Player1.lower() in game and Player2.lower() in game):
      if(Player1 == Player2):
        print("Seri")
      elif((Player1 == "kertas" and Player2 == "batu") or (Player1 == "gunting" and Player2 == "kertas") or (Player1 == "batu" and Player2 == "gunting")):
        print("Pemain 1")
      else:
        print("Pemain 2")
    else:
      print("Input tidak valid!. Gunakan \"batu\", \"gunting\" dan \"kertas\" tanpa tanda kutip!")
# Out:
# Seri
# Pemain 1
# Pemain 2
# Pemain 2
# Seri
# Pemain 1
# Pemain 1
# Pemain 2
# Seri

# %%
# !pip install pillow
